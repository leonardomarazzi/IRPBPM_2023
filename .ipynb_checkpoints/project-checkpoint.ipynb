# %% [markdown]
# # Project of ana and leo

# %%
import pandas as pd
import statistics
import warnings
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from function import Utils
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from pandas.api.types import is_numeric_dtype
import numpy as np
from IPython.display import display

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data loading

# %%
df = pd.read_csv("hmw/hospital_billing.csv",index_col=0)

# %%
df.head(2)
# Out:
#   case_id activity lifecycle resource            timestamp actorange actred  \
# 1       A      NEW  complete     ResA  2012-12-16 19:33:10       NaN    NaN
# 2       A      FIN  complete      NaN  2013-12-15 19:00:37       NaN    NaN
#
#   blocked casetype closecode  ... iscancelled isclosed msgcode msgcount  \
# 1   False        A       NaN  ...       False     True     NaN      NaN
# 2     NaN      NaN         A  ...         NaN      NaN     NaN      NaN
#
#   msgtype speciality        state version  activity_instance_id .order
# 1     NaN          A  In progress     NaN                     1      1
# 2     NaN        NaN       Closed     NaN                     2      2
#
# [2 rows x 25 columns]

# %% [markdown]
# ## Data preprocessing

# %%
input = {
    "case_id" : "caseid",
    "activity" : "activity" ,
    "resource" : "resource" ,
    "timestamp": "ts",
    "lifecycle" : "y"  
}

# Change columns name
df.rename(columns=input,inplace = True)

# Timestamp value in df
df["ts"] = pd.to_datetime(df["ts"])

df["dt"] = Utils.dt(df) # Thisneed to be improved

# %%
Utils.persantage_nan(df)
# Out:
# caseid                   0.002002
# activity                 0.000000
# y                        0.000000
# resource                47.198254
# ts                       0.000000
# actorange               85.724010
# actred                  85.693980
# blocked                 79.980381
# casetype                79.642049
# closecode               84.793097
# diagnosis               80.344738
# flaga                   79.980381
# flagb                   79.980381
# flagc                   85.693980
# flagd                   79.966367
# iscancelled             78.014454
# isclosed                79.780185
# msgcode                 99.725731
# msgcount                85.591880
# msgtype                 99.725731
# speciality              79.980381
# state                   15.721407
# version                 85.021321
# activity_instance_id     0.000000
# .order                   0.000000
# dt                       0.000000
# dtype: float64

# %%
df = Utils.predict_null_value(colum="state",df=df)

# %%
df = Utils.predict_null_value(colum="resource",df=df)

# %%
df = Utils.prod_nan_with_treshold(df)
df.head()
# Out:
#   caseid activity         y resource                  ts        state  \
# 1      A      NEW  complete     ResA 2012-12-16 19:33:10  In progress
# 2      A      FIN  complete     ResA 2013-12-15 19:00:37       Closed
# 3      A  RELEASE  complete     ResA 2013-12-16 03:53:38     Released
# 4      A  CODE OK  complete     ResA 2013-12-17 12:56:29  In progress
# 5      A   BILLED  complete     ResB 2013-12-19 03:44:31       Billed
#
#    activity_instance_id  .order                dt  state_was_null  \
# 1                     1       1 363 days 23:27:27           False
# 2                     2       2   0 days 08:53:01           False
# 3                     3       3   1 days 09:02:51           False
# 4                     4       4   1 days 14:48:02            True
# 5                     5       5   1 days 14:48:02           False
#
#    resource_was_null
# 1              False
# 2               True
# 3               True
# 4               True
# 5              False

# %%
df_grouped = df.groupby(["caseid"]).agg(list).reset_index()

# %%
df_grouped = Utils.reduce_list_columns(df_grouped)

# %%
Utils.display_columns_to_aggragate(df_grouped)
# Out:
#                                                activity  \
# 0                  [NEW, FIN, RELEASE, CODE OK, BILLED]
# 1     [NEW, CHANGE DIAGN, FIN, RELEASE, CODE OK, BIL...
# 2                                                 [NEW]
# 3                                                 [NEW]
# 4     [NEW, CHANGE DIAGN, FIN, RELEASE, CODE OK, BIL...
# ...                                                 ...
# 9994       [NEW, FIN, RELEASE, CODE OK, REOPEN, DELETE]
# 9995                                              [NEW]
# 9996  [NEW, CHANGE DIAGN, FIN, RELEASE, CODE OK, BIL...
# 9997               [NEW, FIN, RELEASE, CODE OK, BILLED]
# 9998  [NEW, CHANGE DIAGN, FIN, RELEASE, CODE OK, BIL...
#
#                                      resource  \
# 0              [ResA, ResA, ResA, ResA, ResB]
# 1       [ResHA, ResI, ResA, ResA, ResA, ResB]
# 2                                     [ResJA]
# 3                                     [ResJA]
# 4     [ResVG, ResJA, ResA, ResA, ResJA, ResB]
# ...

# %%
#Some colomns have no importance in the process so we drop them
df_grouped = df_grouped.drop(['EventID','OfferID','ts','OfferID_was_null'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 2
#       1 #Some colomns have no importance in the process so we drop them
# ----> 2 df_grouped = df_grouped.drop(['EventID','OfferID','ts','OfferID_was_null'],axis=1)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
# ...

# %%
df_grouped_agg = Utils.aggregation_encoding(df_grouped,df)

# %%
df_grouped_agg

# %% [markdown]
# ## Logs encoding

# %% [markdown]
# i think: activity - onehot?, variant - one hot, action, onehot, event origin - onehot, liofecycle - one hot

# %% [markdown]
# ## Model selection

# %% [markdown]
# ## Evaluation of results
